# %%
# 見通しの悪いプログラム
student_list = ['浅木', '松田']
for student in student_list:
  print(f'{student}さんの試験結果を入力してください')
  network = int(input('ネットワークの得点？ >> '))
  database = int(input('データベースの得点？ >> '))
  security = int(input('セキュリティの得点？ >> '))
  if student == '浅木':
    asagi_scores = [network, database, security]
    asagi_avg = sum(asagi_scores) / len(asagi_scores)
  else:
    matsuda_scores = [network, database, security]
    matsuda_avg = sum(matsuda_scores) / len(matsuda_scores)
print(f'浅木さんの平均点は{asagi_avg}です')
print(f'松田さんの平均点は{matsuda_avg}です')
# Out:
# 浅木さんの試験結果を入力してください
# ネットワークの得点？ >> 90
# データベースの得点？ >> 88
# セキュリティの得点？ >> 92
# 松田さんの試験結果を入力してください
# ネットワークの得点？ >> 50
# データベースの得点？ >> 40
# セキュリティの得点？ >> 60
# 浅木さんの平均点は90.0です
# 松田さんの平均点は50.0です

# %%
# 見通しがよくなったプログラム
# 得点を入力
asagi_scores = input_scores('浅木')
matsuda_scores = input_scores('松田')
# 平均点を計算
asagi_avg = calc_avg(asagi_scores)
matsuda_avg = calc_avg(matsuda_scores)
# 結果を出力
output_result('浅木', asagi_avg)
output_result('松田', matsuda_avg)

# %%
# hello関数の定義
def hello():
  print('こんにちは。工藤です')   # インデントが必要

# %%
# hello関数の定義と呼び出し
def hello():
  print('こんにちは。工藤です')

hello()   # 呼び出し
# Out:
# こんにちは。工藤です

# %%
# input_scores関数の変数nameに代入するつもり
def input_scores():
  name = '' # 空の変数nameを準備
  print(f'{name}の試験結果を入力してください')

name = '浅木'
input_scores()
name = '松田'
input_scores()
# Out:
# の試験結果を入力してください
# の試験結果を入力してください

# %%
# hello関数に引数を受け渡す
def hello(name):    # 呼び出し時に渡されるで0田を受け取る変数を準備
  print(f'こんにちは、{name}です。')

hello('浅木')       # 呼び出しと同時に「浅木」を渡す
hello('松田')       # 呼び出しと同時に「松田」を渡す
# Out:
# こんにちは、浅木です。
# こんにちは、松田です。

# %%
# 複数の引数を渡す
def profile(name, age, hobby):
  print(f'私の名前は{name}です。')
  print(f'年齢は{age}です。')
  print(f'趣味は{hobby}です。')

profile('浅木', 24, 'カフェ巡り')
# Out:
# 私の名前は浅木です。
# 年齢は24です。
# 趣味はカフェ巡りです。

# %%
# リストの平均を求めるclac_average関数
def calc_average(scores):           # リストを受け取る引数
  avg = sum(scores) / len(scores)   # 受け取ったリストに格納されている得点の平均を求める
  print(f'平均点は{avg}です')

# %%
# input_scores関数とcalc_average関数
def input_scores(name):                     # 得点入力を担当する関数
  print(f'{name}さんの試験結果を入力してください')
  network = int(input('ネットワークの得点？ >> '))
  database = int(input('データベースの得点？ >> '))
  security = int(input('セキュリティの得点？ >> '))
  scores = [network, database, security]    # 入力された得点をローカル変数scoresにリストとして代入

def calc_average(scores):                   # 平均算出を担当する関数
  avg = sum(scores) / len(scores)
  print(f'平均点は{avg}です')

# input_scores関数とcalc_average関数を呼び出す
input_scores('浅木')
calc_average(scores)                        # ここでエラーが発生
# Out:
# 浅木さんの試験結果を入力してください
# ネットワークの得点？ >> 90
# データベースの得点？ >> 88
# セキュリティの得点？ >> 92
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1031194699.py in <cell line: 0>()
#      13 # input_scores関数とcalc_average関数を呼び出す
#      14 input_scores('浅木')
# ---> 15 calc_average(scores)                        # ここでエラーが発生
#
# NameError: name 'scores' is not defined

# %%
# 足し算の結果を返すplus関数
def plus(x, y):
  answer = x + y
  return answer         # ローカル変数answerの値を戻す

answer = plus(50, 50)   # 変数answerに戻り値が代入される
print(f'足し算の答えは{answer}です')
# Out:
# 足し算の答えは100です

# %%
# 関数を利用して試験結果を計算する
def input_scores(name):                       # 得点入力を担当する関数
  print(f'{name}さんの試験結果を入力してください')
  network = int(input('ネットワークの得点？ >> '))
  database = int(input('データベースの得点？ >> '))
  security = int(input('セキュリティの得点？ >> '))
  scores = [network, database, security]
  return scores

def calc_average(scores):                     # 平均の算出を担当する関数
  avg = sum(scores) / len(scores)
  return avg

def output_result(name, avg):                 # 平均点の出力を担当する関数
  print(f'{name}さんの平均点は{avg}です')

# 浅木と松田の得点入力
asagi_scores = input_scores('浅木')
matsuda_scores = input_scores('松田')
# 平均点を計算
asagi_avg = calc_average(asagi_scores)        # input_scores関数の戻り値を引数に渡す
matsuda_avg = calc_average(matsuda_scores)    # input_scores関数の戻り値を引数に渡す
# 結果を出力
output_result('浅木', asagi_avg)              # calc_average関数の戻り値を引数に渡す
output_result('松田', matsuda_avg)            # calc_average関数の戻り値を引数に渡す
# Out:
# 浅木さんの試験結果を入力してください
# ネットワークの得点？ >> 90
# データベースの得点？ >> 88
# セキュリティの得点？ >> 92
# 松田さんの試験結果を入力してください
# ネットワークの得点？ >> 50
# データベースの得点？ >> 40
# セキュリティの得点？ >> 60
# 浅木さんの平均点は90.0です
# 松田さんの平均点は50.0です

# %%
# 2つの戻り値を返す？
def plus_and_minus(a, b):
  return a + b, a - b   # 和と差の2つの値が戻り値のように見える

next, prev = plus_and_minus(1978, 1)
print(next)
print(prev)
# Out:
# 1979
# 1977

# %%
# 戻り値のタプルをアンバック代入
def plus_and_minus(a, b):
  return (a + b, a - b)                 # 要素数2のタプルを1つ返しているだけ

(next, prev) = plus_and_minus(1978, 1)    # 返ってきたタプルをアンバック代入しているだけ
print(next)
print(prev)
# Out:
# 1979
# 1977

# %%
# 松田くんの食生活を表示する
def eat(breakfast, lunch, dinner):
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')

print('8月1日')
eat('トースト', 'おにぎり', 'カレー')
print('8月2日')
eat('納豆ごはん', 'ラーメン', 'カレー')
print('8月3日')
eat('バナナ', 'そば', '焼き肉')
print('8月4日')
eat('サンドウィッチ', 'しゅうまい弁当', 'カレー')
# Out:
# 8月1日
# 朝はトーストを食べました
# 昼はおにぎりを食べました
# 夜はカレーを食べました
# 8月2日
# 朝は納豆ごはんを食べました
# 昼はラーメンを食べました
# 夜はカレーを食べました
# 8月3日
# 朝はバナナを食べました
# 昼はそばを食べました
# 夜は焼き肉を食べました
# 8月4日
# 朝はサンドウィッチを食べました
# 昼はしゅうまい弁当を食べました
# 夜はカレーを食べました

# %%
# 松田くんの言うまでもない食生活を表示する
def eat(breakfast, lunch, dinner = 'カレー'):   # 引数dinnerにデフォルト値を指定
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')

print('8月1日')
eat('トースト', 'おにぎり')                     # 引数dinnerの実引数を省略
print('8月2日')
eat('納豆ごはん', 'ラーメン')                   # 引数dinnerの実引数を省略
print('8月3日')
eat('バナナ', 'そば', '焼き肉')
print('8月4日')
eat('サンドウィッチ', 'しゅうまい弁当')         # 引数dinnerの実引数を省略
# Out:
# 8月1日
# 朝はトーストを食べました
# 昼はおにぎりを食べました
# 夜はカレーを食べました
# 8月2日
# 朝は納豆ごはんを食べました
# 昼はラーメンを食べました
# 夜はカレーを食べました
# 8月3日
# 朝はバナナを食べました
# 昼はそばを食べました
# 夜は焼き肉を食べました
# 8月4日
# 朝はサンドウィッチを食べました
# 昼はしゅうまい弁当を食べました
# 夜はカレーを食べました

# %%
"""
デフォルト引数の制約
デフォルト引数が指定された仮引数より後ろに、デフォルト引数がない仮引数を定義してはならない
"""
def eat(breakfast = 'サンドウィッチ', lunch, dinner):
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')
# Out:
#   File "/tmp/ipython-input-2779208000.py", line 5
#     def eat(breakfast = 'サンドウィッチ', lunch, dinner):
#                                    ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
# 夜がカレーじゃない日のeat関数の呼び出し
def eat(breakfast, lunch = 'ラーメン', dinner = 'カレー'):    # 昼は基本ラーメン、夜は基本カレー
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')

eat('納豆ごはん', 'ラーメン', 'カレーうどん')                 # 昼は基本ラーメンなので、本当は省略したいが…
eat('納豆ごはん', 'カレーうどん')                             # 誤って解釈されてしまう
# Out:
# 朝は納豆ごはんを食べました
# 昼はラーメンを食べました
# 夜はカレーうどんを食べました
# 朝は納豆ごはんを食べました
# 昼はカレーうどんを食べました
# 夜はカレーを食べました

# %%
# 夜がカレーじゃない日のeat関数の呼び出し(キーワード指定)
def eat(breakfast, lunch = 'ラーメン', dinner = 'カレー'):
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')

eat(breakfast = '納豆ごはん', dinner = 'カレーうどん')
eat(dinner = 'カレーうどん', breakfast = '納豆ごはん')
eat('納豆ごはん', dinner = 'カレーうどん')
# Out:
# 朝は納豆ごはんを食べました
# 昼はラーメンを食べました
# 夜はカレーうどんを食べました
# 朝は納豆ごはんを食べました
# 昼はラーメンを食べました
# 夜はカレーうどんを食べました
# 朝は納豆ごはんを食べました
# 昼はラーメンを食べました
# 夜はカレーうどんを食べました

# %%
# おやつも食べた日のeat関数の呼び出し
def eat(breakfast, lunch, dinner = 'カレー', desserts = ()):          # 要素数0のタプルをデフォルト引数に指定
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')
  for d in desserts:
    print(f'おやつに{d}を食べました')

eat('トースト', 'パスタ', 'カレー', ('アイス', 'チョコ', 'パフェ'))   # おやつの部分は丸カッコで囲んでタプルにする
# Out:
# 朝はトーストを食べました
# 昼はパスタを食べました
# 夜はカレーを食べました
# おやつにアイスを食べました
# おやつにチョコを食べました
# おやつにパフェを食べました

# %%
# おやつも食べた日のeat関数の呼び出し(可変長引数を利用)
def eat(breakfast, lunch, dinner = 'カレー', *desserts):            # dessertsは可変長引数を表明
  print(f'朝は{breakfast}を食べました')
  print(f'昼は{lunch}を食べました')
  print(f'夜は{dinner}を食べました')
  for d in desserts:
    print(f'おやつに{d}を食べました')

eat('トースト', 'パスタ', 'カレー', 'アイス', 'チョコ', 'カレー')   # 後半部分が1つのタプルとして仮引数dessertsに引き渡される
# Out:
# 朝はトーストを食べました
# 昼はパスタを食べました
# 夜はカレーを食べました
# おやつにアイスを食べました
# おやつにチョコを食べました
# おやつにカレーを食べました

# %%
# ディクショナリを用いた可変長引数
def eat(**kwargs):
  for key in kwargs:                                                      # for文にディクショナリを指定するとキーが順番に取り出される
    print(f'{key}に{kwargs[key]}を食べました')

eat(朝食 = '納豆', 遅めの昼食 = 'パスタ', 夕方のおやつ = 'カレーパン')    # 1つのディレクショナリとして引数kwargsに渡される
# Out:
# 朝食に納豆を食べました
# 遅めの昼食にパスタを食べました
# 夕方のおやつにカレーパンを食べました

# %%
# 引数を使わずに変数nameの値を受け渡している
name = '松田'
def hello():
  print('こんにちは' + name + 'さん')

hello()
# Out:
# こんにちは松田さん

# %%
# 関数の中からグローバル変数に代入できる？
name = '松田'
def change_name():
  name = '浅木'   # グローバル変数nameに代入しているつもり
def hello():
  print('こんにちは' + name + 'さん')

change_name()
hello()
# Out:
# こんにちは松田さん

# %%
# global文を用いてグローバル変数に代入する
name = '松田'
def change_name():
  global name     # この関数におけるnameはローカル変数ではなくグローバル変数であると宣言
  name = '浅木'   # グローバル変数nameへ代入している
def hello():
  print('こんにちは' + name + 'さん')

change_name()
hello()
# Out:
# こんにちは浅木さん

# %%
# 練習5-2
def is_leapyear(year):
  return (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0)

current_year = int(input('うるう年判定：西暦を入力してください >> '))
if is_leapyear(current_year):
  print(f'西暦{current_year}年は、うるう年です')
else:
  print(f'西暦{current_year}年は、うるう年ではありません')
# Out:
# うるう年判定：西暦を入力してください >> 100
# 西暦100年は、うるう年ではありません

# %%
# 練習5-5
# 計算データの入力
amount = int(input('支払い総額を入力してください >> '))
people = int(input('参加人数を入力してください >> '))

# 割り勘の計算
dnum = amount / people    # 総額を人数で割る(端数も保持)
pay = dnum // 100 * 100   # 100円未満を切り捨てる
if dnum > pay:            # 元の値と比較して、
  pay = int(pay + 100)    # 小さければ100円未満があったので上乗せ

# 幹事の支払い額の計算
payorg = amount - pay * (people - 1)

#結果の表示
print('*** 支払い額 ***')
print(f'1人あたり{pay}円({people}人)、幹事は{payorg}円です')
# Out:
# 支払い総額を入力してください >> 1250
# 参加人数を入力してください >> 3
# *** 支払い額 ***
# 1人あたり500円(3人)、幹事は250円です

# %%
# 練習5-5(関数に部品化)
# データの入力
def int_input(msg):
  return int(input(f'{msg}を入力してください >> '))

# 割り勘の計算(幹事の支払い額の計算)
def calc_payment(amount, people = 2):
  dnum = amount / people
  pay = dnum // 100 * 100
  if dnum > pay:
    pay = int(pay + 100)
  payorg = amount - pay * (people - 1)
  return [int(pay), int(payorg)]

# 結果の表示
def show_payment(pay, payorg, people = 2):
  print('*** 支払い金額 ***')
  print(f'1人あたり{pay}円({people}人)、幹事は{payorg}円です')

# 関数を用いたプログラム
amount = int_input('支払い総額')
people = int_input('参加人数')
[pay, payorg] = calc_payment(amount, people)
show_payment(pay, payorg, people)
# Out:
# 支払い総額を入力してください >> 1250
# 参加人数を入力してください >> 3
# *** 支払い金額 ***
# 1人あたり500円(3人)、幹事は250円です
