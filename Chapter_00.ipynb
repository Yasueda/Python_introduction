# %%
# はじめてのPythonプログラム
print('Hello, World')
# Out:
# Hello, World

# %%
# 浅木さんが書き換えたプログラム
print('浅木薫、がんばります！！')
# Out:
# 浅木薫、がんばります！！

# %%
# 松田くんが書き換えたプログラム(エラー)
print('松田くん、かっこいい！　最高！)
# Out:
#   File "/tmp/ipython-input-1625649983.py", line 2
#     print('松田くん、かっこいい！　最高！)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 複数の文字列を表示する
print('工藤 慎平')
print('30歳')
print('三度の飯より数学が好き')
# Out:
# 工藤 慎平
# 30歳
# 三度の飯より数学が好き

# %%
# コメントを入れたプログラム
"""
自己紹介プログラム
作成者：工藤 慎平
作成日：20XX年XX月XX日
"""

# 名前と特技を表示
print('僕の名前は工藤 慎平')
print('三度の飯より数学が好き')
# Out:
# 僕の名前は工藤 慎平
# 三度の飯より数学が好き
